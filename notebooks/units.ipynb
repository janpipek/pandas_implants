# %% [markdown]
# # UnitsExtensionArray

# %%
import numpy as np
import pandas as pd
import pandas_implants as pi
import astropy.units as u

# %% [markdown]
# ## Dtype

# %%
m_type = pi.UnitsDtype(u.m)
m_type
# Out:
# UnitsDtype("m")

# %%
m_type.name
# Out:
# 'unit[m]'

# %%
m_type.unit
# Out:
# Unit("m")

# %% [markdown]
# ## UnitsExtensionArray simple example

# %%
peaks = pd.read_csv("peaks.csv")
peaks
# Out:
#                 name  height
# 0       Mount Elbert   14440
# 1      Mount Massive   14428
# 2      Mount Harvard   14421
# 3        Blanca Peak   14351
# 4      La Plata Peak   14343
# 5   Uncompahgre Peak   14321
# 6      Crestone Peak   14300
# 7      Mount Lincoln   14293
# 8        Castle Peak   14279
# 9         Grays Peak   14278
# 10      Mount Antero   14276
# 11       Mount Evans   14271
# 12        Longs Peak   14259
# 13      Mount Wilson   14252
# 14   Mount Princeton   14204
# 15        Mount Yale   14200
# 16       Maroon Peak   14163
# 17    Mount Sneffels   14158
# 18      Capitol Peak   14137
# 19        Pikes Peak   14115

# %%
# Specify the column type
peaks["height"] = peaks["height"].astype("unit[ft]")
peaks
# Out:
#                 name     height
# 0       Mount Elbert 14440.0 ft
# 1      Mount Massive 14428.0 ft
# 2      Mount Harvard 14421.0 ft
# 3        Blanca Peak 14351.0 ft
# 4      La Plata Peak 14343.0 ft
# 5   Uncompahgre Peak 14321.0 ft
# 6      Crestone Peak 14300.0 ft
# 7      Mount Lincoln 14293.0 ft
# 8        Castle Peak 14279.0 ft
# 9         Grays Peak 14278.0 ft
# 10      Mount Antero 14276.0 ft
# 11       Mount Evans 14271.0 ft
# 12        Longs Peak 14259.0 ft
# 13      Mount Wilson 14252.0 ft
# 14   Mount Princeton 14204.0 ft
# 15        Mount Yale 14200.0 ft
# 16       Maroon Peak 14163.0 ft
# 17    Mount Sneffels 14158.0 ft
# 18      Capitol Peak 14137.0 ft
# 19        Pikes Peak 14115.0 ft

# %%
# I don't understand that
peaks["height"].units.to_si()
# Out:
# 0             4401.312 m
# 1            4397.6544 m
# 2            4395.5208 m
# 3            4374.1848 m
# 4            4371.7464 m
# 5    4365.040800000001 m
# 6              4358.64 m
# 7            4356.5064 m
# 8            4352.2392 m
# 9            4351.9344 m
# 10           4351.3248 m
# 11           4349.8008 m
# 12           4346.1432 m
# 13           4344.0096 m
# 14           4329.3792 m
# 15             4328.16 m
# 16           4316.8824 m
# 17           4315.3584 m
# 18   4308.957600000001 m
# 19            4302.252 m
# Name: height, dtype: unit[m]

# %%
peaks.units.to_si()
# Out:
#                 name              height
# 0       Mount Elbert          4401.312 m
# 1      Mount Massive         4397.6544 m
# 2      Mount Harvard         4395.5208 m
# 3        Blanca Peak         4374.1848 m
# 4      La Plata Peak         4371.7464 m
# 5   Uncompahgre Peak 4365.040800000001 m
# 6      Crestone Peak           4358.64 m
# 7      Mount Lincoln         4356.5064 m
# 8        Castle Peak         4352.2392 m
# 9         Grays Peak         4351.9344 m
# 10      Mount Antero         4351.3248 m
# 11       Mount Evans         4349.8008 m
# 12        Longs Peak         4346.1432 m
# 13      Mount Wilson         4344.0096 m
# 14   Mount Princeton         4329.3792 m
# 15        Mount Yale           4328.16 m
# 16       Maroon Peak         4316.8824 m
# 17    Mount Sneffels         4315.3584 m
# 18      Capitol Peak 4308.957600000001 m
# 19        Pikes Peak          4302.252 m

# %%
dent_blanche = 4357 * pi.Unit("m")
peaks["tall"] = peaks.height > dent_blanche  # Will show wrong result in pandas 1.0
peaks
# Out:
#                 name     height   tall
# 0       Mount Elbert 14440.0 ft   True
# 1      Mount Massive 14428.0 ft   True
# 2      Mount Harvard 14421.0 ft   True
# 3        Blanca Peak 14351.0 ft   True
# 4      La Plata Peak 14343.0 ft   True
# 5   Uncompahgre Peak 14321.0 ft   True
# 6      Crestone Peak 14300.0 ft   True
# 7      Mount Lincoln 14293.0 ft  False
# 8        Castle Peak 14279.0 ft  False
# 9         Grays Peak 14278.0 ft  False
# 10      Mount Antero 14276.0 ft  False
# 11       Mount Evans 14271.0 ft  False
# 12        Longs Peak 14259.0 ft  False
# 13      Mount Wilson 14252.0 ft  False
# 14   Mount Princeton 14204.0 ft  False
# 15        Mount Yale 14200.0 ft  False
# 16       Maroon Peak 14163.0 ft  False
# 17    Mount Sneffels 14158.0 ft  False
# 18      Capitol Peak 14137.0 ft  False
# 19        Pikes Peak 14115.0 ft  False

# %% [markdown]
# ## Another example

# %%
temps = pd.DataFrame([
    ["Prague", 23],
    ["Ostrava", 27],
    ["Nairobi", 31],
    ["Cairo", 47],
    ["Johannesburg", 13]
], columns=["city", "temp"])
temps
# Out:
#            city  temp
# 0        Prague    23
# 1       Ostrava    27
# 2       Nairobi    31
# 3         Cairo    47
# 4  Johannesburg    13

# %%
temps["temp"] = temps["temp"].astype("unit[deg_C]")
temps
# Out:
#            city       temp
# 0        Prague 23.0 deg_C
# 1       Ostrava 27.0 deg_C
# 2       Nairobi 31.0 deg_C
# 3         Cairo 47.0 deg_C
# 4  Johannesburg 13.0 deg_C

# %%
temps["temp"].factorize()
# Out:
# (array([0, 1, 2, 3, 4], dtype=int64),
#  Index([23.0, 27.0, 31.0, 47.0, 13.0], dtype='object'))

# %%
temps.dtypes
# Out:
# city         object
# temp    unit[deg_C]
# dtype: object

# %%
temps["temp_f"] = temps["temp"].units.to("deg_F")
temps["temp_K"] = temps["temp"].units.to("K")
temps
# Out:
#            city       temp                   temp_f   temp_K
# 0        Prague 23.0 deg_C               73.4 deg_F 296.15 K
# 1       Ostrava 27.0 deg_C               80.6 deg_F 300.15 K
# 2       Nairobi 31.0 deg_C  87.80000000000001 deg_F 304.15 K
# 3         Cairo 47.0 deg_C 116.60000000000001 deg_F 320.15 K
# 4  Johannesburg 13.0 deg_C 55.400000000000006 deg_F 286.15 K

# %% [markdown]
# ## Advanced computations ("running diary")

# %%
df = pd.DataFrame({
    "days": ["Monday", "Tuesday", "Thursday", "Saturday"],
    "distance": pd.Series([10, 12, 22, 18], dtype="unit[km]"),
    "time": pd.Series([50, 60, 120, 108], dtype="unit[min]")
})
df = df.set_index("days")
df = df.reindex(["Monday", "Tuesday", "Wednesday", "Thursday",
                 "Friday", "Saturday", "Sunday"])
df
# Out:
#           distance      time
# days
# Monday     10.0 km  50.0 min
# Tuesday    12.0 km  60.0 min
# Wednesday   nan km   nan min
# Thursday   22.0 km 120.0 min
# Friday      nan km   nan min
# Saturday   18.0 km 108.0 min
# Sunday      nan km   nan min

# %%
df["speed"] = (df["distance"] / df["time"]).units.to("km/h")
df["speed[imperial]"] = df["speed"].units.to("mi / h")
df["pace[min/km]"] = (df["time"] / df["distance"] * u.Quantity("1 km")).astype("timedelta64[ns]")  # Will fail in pandas 1.0
df["fast"] = df["speed"] > u.Quantity("11 km/h")
df
# Out:
#           distance      time       speed          speed[imperial]  \
# days
# Monday     10.0 km  50.0 min 12.0 km / h 7.456454306848009 mi / h
# Tuesday    12.0 km  60.0 min 12.0 km / h 7.456454306848009 mi / h
# Wednesday   nan km   nan min  nan km / h               nan mi / h
# Thursday   22.0 km 120.0 min 11.0 km / h 6.835083114610675 mi / h
# Friday      nan km   nan min  nan km / h               nan mi / h
# Saturday   18.0 km 108.0 min 10.0 km / h  6.21371192237334 mi / h
# Sunday      nan km   nan min  nan km / h               nan mi / h
#
#              pace[min/km]   fast
# days
# Monday           00:05:00   True
# Tuesday          00:05:00   True
# Wednesday             NaT  False
# Thursday  00:05:27.272727  False
# Friday                NaT  False
# Saturday         00:06:00  False
# Sunday                NaT  False
